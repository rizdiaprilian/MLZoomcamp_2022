# %% [markdown]
# ### Question 1
#
# What's the version of pipenv you installed?
#
# #### Answer: 22.2.2

# %% [markdown]
# ### Question 2
#
# What's the first hash for scikit-learn you get in Pipfile.lock?
#
# #### Answer:
#
# ![image.png](attachment:d860c696-a38f-489d-8ff4-e06c2a493801.png)

# %% [markdown]
# ### Question 3
#
# What's the probability that this client will get a credit card?
#
# #### Answer: 0.9282218 -> 0.993

# %% [markdown]
# #### Checking their checksum
#
# ![image.png](attachment:1775ea01-8b08-4c67-aaf8-23365a4288d7.png)

# %% [markdown]
# ### Question 4
#
# What's the probability that this client will get a credit card?
#
# #### Answer: 0.9282218 -> 0.928

# %% [markdown]
# ### Question 5
#
# So what's the size of this base image?
#
# #### Answer: 125 MB

# %% [markdown]
# ### Question 6
#
# What's the probability that this client will get a credit card now?
#
# #### Answer: 0.7692649226628628 -> 0.769
